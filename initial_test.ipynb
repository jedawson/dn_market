# %%
import re
import os
import logging
import datetime
from bs4 import BeautifulSoup

# %%
import json

# %%
# from https://github.com/infosecanon/dminer/blob/master/dminer/ingestion/dreammarket/dreammarket.py
def extract_listings(soup, timestamp):
    """
    Extracts each DreamMarket listing from the given `soup` variable
    (`bs4.BeautifulSoup`) object. The listings will then be associated to
    the passed `timestamp`. Each listing item is then yielded to the
    caller.

    It is notable that there is currently one situation in which a listing
    will be skipped, and that is if there is no `primary_div` found.
    """

    listings = soup.find_all("div", class_="around")
    for listing_element in listings:
        title_div = listing_element.find("div", class_="oTitle")
        primary_div = listing_element.find("div", class_="oOfferBody")
        if not primary_div:
            #self.logger.info("skipping entry:" + repr(title_div.find("a").text.strip()) + "| Reason: No primary_div found.")
            continue

        listing_meta_div = primary_div.find("td", class_="oOfTextDetail")
        vendor_div = listing_meta_div.find("div", class_="oVendor")

        item = {}
        item["market_name"] = "DreamMarket"
        item["listing_name"] = title_div.find("a").text.strip()
        item["timestamp"] = timestamp

        # starting at 1 to avoid the bitcoin icon
        item["listing_price_btc"] = float(listing_meta_div.find("div", class_="oPrice").text.strip()[1:])
        item["listing_escrow"] = primary_div.find("div", class_="escrowBox").text


        vendor_name = list(tag for tag in vendor_div.find_all("a") if tag["href"].startswith("./"))[0].text.strip()
        vendor_transactions = int(vendor_div.find("span", title="Successful transactions").text.lstrip("(").rstrip(")"))
        vendor_rating = vendor_div.find("span", class_="userRating")
        if vendor_rating:
            vendor_rating = float(vendor_rating.text.strip())
        else:
            vendor_rating = float(0)

        item["vendor_name"] = vendor_name
        item["vendor_transactions"] = vendor_transactions
        item["vendor_rating"] = vendor_rating

        yield item

# %%
with open("dreammarket/2015-07-03/market/index.html", encoding = "ISO-8859-1") as fp:
    soup = BeautifulSoup(fp, 'lxml')

# %%
sample_listings = extract_listings(soup, '2015-07-03')

# %%
soup.find_all("div", class_="around")[0]
# Out:
# <div class="around">
# <div class="shopItem shopItem_4485">
# <div class="oImage">
# <a class="productThumbImage_4485" href="./viewProduct?offer=857560.783794" target="_blank">
# <img alt="100g 10 PIN BOWLING HASH" height="132" src="uploadedImage?id=119513.793985&amp;type=thumb" width="176"/>
# </a>
# </div>
# <div class="escrowInfo"><div class="escrowBox withoutEscrow">NO ESCROW</div></div> <div class="hoverInfo ">
# <div class="pdd">
# <div class="text">
# <p>Vendor<br/>
# <a href="./contactMember?member=monetka">monetka</a>
# </p></div>
# </div>
# </div>
# <div class="text oTitle">
# <a class="productThumbImage_4485" href="./viewProduct?offer=857560.783794">
#   			  					100g 10 PIN BOWLING HASH	  			  				</a>
# </div>
# <div class="bottom oPrice">
# 						฿3.34					</div>
# </div>
# </div>

# %%
soup.find_all('script')[2].get_text().split("\n\n\t\n\n\t")[1].split('\n\t')[0].split('= ')[1]
# Out:
# '[{"lid":"4485","lnk":"857560.783794","title":"100g 10 PIN BOWLING HASH","imageId":"119513.793985","sellerOutLink":-1377523590,"btcPriceText":3.34,"localPriceText":"&pound;550","shipsFrom":"UK","isTrustedSeller":true,"domesticCurrencyValue":null,"escrowMethod":"No"},{"lid":"6281","lnk":"946223.929536","title":"50g Budget Rocky Slabs","imageId":"962934.717087","sellerOutLink":-1377523590,"btcPriceText":"0.79","localPriceText":"&pound;130","shipsFrom":"UK","isTrustedSeller":true,"domesticCurrencyValue":null,"escrowMethod":"No"},{"lid":"5436","lnk":"700734.885048","title":"Freezeland 8g Free Shipping ","imageId":"609519.863451","sellerOutLink":513788116,"btcPriceText":"0.354","localPriceText":"&euro;82","shipsFrom":"Germany","isTrustedSeller":true,"domesticCurrencyValue":null,"escrowMethod":"No"},{"lid":"3622","lnk":"527640.525668","title":"PlayBoy Plus.com - [LIFETIME PORN PREMIUM ACCOUNT]","imageId":"119050.912668","sellerOutLink":-1350947825,"btcPriceText":"0.0394","localPriceText":"$10","shipsFrom":"TOR","isTrustedSeller":true,"domesticCurrencyValue":null,"escrowMethod":"Yes"},{"lid":"1281","lnk":"764754.371983","title":"10 grams SUPER SILVER HAZE ||HOLLAND|| AAA+++","imageId":"599296.499093","sellerOutLink":-2081707471,"btcPriceText":"0.478","localPriceText":null,"shipsFrom":"Europe","isTrustedSeller":true,"domesticCurrencyValue":null,"escrowMethod":"Yes"},{"lid":"3607","lnk":"248169.580076","title":"Wicked.com - [LIFETIME PORN PREMIUM ACCOUNT]","imageId":"951437.310372","sellerOutLink":-1350947825,"btcPriceText":"0.0394","localPriceText":"$10","shipsFrom":"TOR","isTrustedSeller":true,"domesticCurrencyValue":null,"escrowMethod":"Yes"},{"lid":"992","lnk":"152548.869509","title":"0,5gr. - HEROIN - #3 - PGP - FREE SHIP-GERMANY ","imageId":"160769.542763","sellerOutLink":653986930,"btcPriceText":"0.212","localPriceText":null,"shipsFrom":"GERMANY","isTrustedSeller":true,"domesticCurrencyValue":null,"escrowMethod":"Yes"},{"lid":"3604","lnk":"302658.450269","title":"VideoBox.com - [LIFETIME PORN PREMIUM ACCOUNT]","imageId":"246883.555984","sellerOutLink":-1350947825,"btcPriceText":"0.0394","localPriceText":"$10","shipsFrom":"TOR","isTrustedSeller":true,"domesticCurrencyValue":null,"escrowMethod":"Yes"},{"lid":"1337","lnk":"649888.997084","title":"Melanotan 2","imageId":"667613.295606","sellerOutLink":1916090551,"btcPriceText":"0.1776","localPriceText":"$45","shipsFrom":"USA","isTrustedSeller":true,"domesticCurrencyValue":null,"escrowMethod":"No"},{"lid":"4106","lnk":"993708.571694","title":"Freezeland 1g","imageId":"609519.863451","sellerOutLink":513788116,"btcPriceText":"0.0518","localPriceText":"&euro;12","shipsFrom":"Germany","isTrustedSeller":true,"domesticCurrencyValue":null,"escrowMethod":"No"},{"lid":"6066","lnk":"539927.68074","title":"Advanced Carding Guide ","imageId":"329605.302028","sellerOutLink":1412451852,"btcPriceText":"0.0394","localPriceText":"$10","shipsFrom":"Kingston","isTrustedSeller":true,"domesticCurrencyValue":null,"escrowMethod":"No"},{"lid":"3210","lnk":"127579.397913","title":"Rick Simpson Hash oil 2g","imageId":"189336.946676","sellerOutLink":-1377523590,"btcPriceText":"0.334","localPriceText":"&pound;55","shipsFrom":"UK","isTrustedSeller":true,"domesticCurrencyValue":null,"escrowMethod":"No"},{"lid":"6046","lnk":"998702.622469","title":"PublicPickups.com - [LIFETIME PORN PREMIUM ACCOUNT","imageId":"294056.943124","sellerOutLink":-1350947825,"btcPriceText":"0.0394","localPriceText":"$10","shipsFrom":"","isTrustedSeller":true,"domesticCurrencyValue":null,"escrowMethod":"Yes"},{"lid":"3472","lnk":"794918.577943","title":"Priority Shipping With Tracking","imageId":"93622.922314","sellerOutLink":1916090551,"btcPriceText":"0.0592","localPriceText":"$15","shipsFrom":"USA","isTrustedSeller":true,"domesticCurrencyValue":null,"escrowMethod":"No"},{"lid":"4096","lnk":"923488.138010","title":"Ak 47 1g ","imageId":"719051.502618","sellerOutLink":513788116,"btcPriceText":"0.0518","localPriceText":"&euro;12","shipsFr ...

# %%
json.loads(soup.find_all('script')[2].get_text().split("\n\n\t\n\n\t")[1].split('\n\t')[0].split('= ')[1])
# Out:
# [{'lid': '4485',
#   'lnk': '857560.783794',
#   'title': '100g 10 PIN BOWLING HASH',
#   'imageId': '119513.793985',
#   'sellerOutLink': -1377523590,
#   'btcPriceText': 3.34,
#   'localPriceText': '&pound;550',
#   'shipsFrom': 'UK',
#   'isTrustedSeller': True,
#   'domesticCurrencyValue': None,
#   'escrowMethod': 'No'},
#  {'lid': '6281',
#   'lnk': '946223.929536',
#   'title': '50g Budget Rocky Slabs',
#   'imageId': '962934.717087',
#   'sellerOutLink': -1377523590,
#   'btcPriceText': '0.79',
#   'localPriceText': '&pound;130',
#   'shipsFrom': 'UK',
#   'isTrustedSeller': True,
#   'domesticCurrencyValue': None,
#   'escrowMethod': 'No'},
#  {'lid': '5436',
#   'lnk': '700734.885048',
#   'title': 'Freezeland 8g Free Shipping ',
#   'imageId': '609519.863451',
#   'sellerOutLink': 513788116,
#   'btcPriceText': '0.354',
#   'localPriceText': '&euro;82',
#   'shipsFrom': 'Germany',
#   'isTrustedSeller': True,
#   'domesticCurrencyValue': None,
#   'escrowMethod': 'No'},
#  {'lid': '3622',
#   'lnk': '527640.525668',
#   'title': 'PlayBoy Plus.com - [LIFETIME PORN PREMIUM ACCOUNT]',
#   'imageId': '119050.912668',
#   'sellerOutLink': -1350947825,
#   'btcPriceText': '0.0394',
#   'localPriceText': '$10',
#   'shipsFrom': 'TOR',
#   'isTrustedSeller': True,
#   'domesticCurrencyValue': None,
#   'escrowMethod': 'Yes'},
#  {'lid': '1281',
#   'lnk': '764754.371983',
#   'title': '10 grams SUPER SILVER HAZE ||HOLLAND|| AAA+++',
#   'imageId': '599296.499093',
#   'sellerOutLink': -2081707471,
#   'btcPriceText': '0.478',
#   'localPriceText': None,
#   'shipsFrom': 'Europe',
#   'isTrustedSeller': True,
#   'domesticCurrencyValue': None,
#   'escrowMethod': 'Yes'},
#  {'lid': '3607',
#   'lnk': '248169.580076',
#   'title': 'Wicked.com - [LIFETIME PORN PREMIUM ACCOUNT]',
#   'imageId': '951437.310372',
#   'sellerOutLink': -1350947825,
#   'btcPriceText': '0.0394',
#   'localPriceText': '$10',
#   'shipsFrom': 'TOR',
#   'isTrustedSeller': True,
#   'domesticCurrencyValue': None,
#   'escrowMethod': 'Yes'},
#  {'lid': '992',
#   'lnk': '152548.869509',
#   'title': '0,5gr. - HEROIN - #3 - PGP - FREE SHIP-GERMANY ',
#   'imageId': '160769.542763',
#   'sellerOutLink': 653986930,
#   'btcPriceText': '0.212',
#   'localPriceText': None,
#   'shipsFrom': 'GERMANY',
#   'isTrustedSeller': True,
#   'domesticCurrencyValue': None,
#   'escrowMethod': 'Yes'},
#  {'lid': '3604',
#   'lnk': '302658.450269',
#   'title': 'VideoBox.com - [LIFETIME PORN PREMIUM ACCOUNT]',
#   'imageId': '246883.555984',
#   'sellerOutLink': -1350947825,
#   'btcPriceText': '0.0394',
#   'localPriceText': '$10',
#   'shipsFrom': 'TOR',
#   'isTrustedSeller': True,
#   'domesticCurrencyValue': None,
#   'escrowMethod': 'Yes'},
#  {'lid': '1337',
#   'lnk': '649888.997084',
#   'title': 'Melanotan 2',
#   'imageId': '667613.295606',
#   'sellerOutLink': 1916090551,
#   'btcPriceText': '0.1776',
#   'localPriceText': '$45',
#   'shipsFrom': 'USA',
#   'isTrustedSeller': True,
#   'domesticCurrencyValue': None,
#   'escrowMethod': 'No'},
#  {'lid': '4106',
#   'lnk': '993708.571694',
#   'title': 'Freezeland 1g',
#   'imageId': '609519.863451',
#   'sellerOutLink': 513788116,
#   'btcPriceText': '0.0518',
#   'localPriceText': '&euro;12',
#   'shipsFrom': 'Germany',
#   'isTrustedSeller': True,
#   'domesticCurrencyValue': None,
#   'escrowMethod': 'No'},
#  {'lid': '6066',
#   'lnk': '539927.68074',
#   'title': 'Advanced Carding Guide ',
#   'imageId': '329605.302028',
#   'sellerOutLink': 1412451852,
#   'btcPriceText': '0.0394',
#   'localPriceText': '$10',
#   'shipsFrom': 'Kingston',
#   'isTrustedSeller': True,
#   'domesticCurrencyValue': None,
#   'escrowMethod': 'No'},
#  {'lid': '3210',
#   'lnk': '127579.397913',
#   'title': 'Rick Simpson Hash oil 2g',
#   'imageId': '189336.946676',
#   'sellerOutLink': -1377523590,
#   'btcPriceText': '0.334',
#   'localPriceText': '&pound;55',
#   'shipsFrom': 'UK',
#   'isTrustedSeller': True,
#   'domesticCurrencyValue': None,
#   'escrowMethod': 'No'},
#  {'lid': '6046',
#   'lnk': '998702.622469',
#   'title': 'PublicPickups.com - [LIFETIME PORN PREMIUM ACCOUNT',
#   'imageId': '294056.943124',
#   'sellerOutLink': -1350947825,
#   'btcPriceText': '0.0394',
#   'localPriceText': '$10',
#   'shipsFrom': '',
#   'isTrustedSeller': True,
#   'domesticCurrencyValue': None,
#   'escrowMethod': 'Yes'},
#  {'lid': '3472',
#   'lnk': '794918.577943',
#   'title': 'Priority Shipping With Tracking',
#   'imageId': '93622.922314',
#   'sellerOutLink': 1916090551,
#   'btcPriceText': '0.0592',
#   'localPriceText': '$15',
#   'shipsFrom': 'USA',
#   'isTrustedSeller': True,
#   'domesticCurrencyValue': None,
#   'escrowMethod': 'No'},
#  {'lid': '4096',
#   'lnk': '923488.138010',
#   'title': 'Ak 47 1g ',
#   'imageId': '719051.502618',
#   'sellerOutLink': 513788116,
#   'btcPriceText': '0.0518',
#   'localPriceText': '&euro;12',
#   'shipsFrom': 'germany',
#   'isTrustedSeller': True,
#   'domesticCurrencyValue': None,
#   'escrowMethod': 'No'},
#  {'lid': '4099',
#   'lnk': '343366.39497',
#   'title': 'Dark Star 2g',
#   'imageId': '65459.403887',
#   'sellerOutLink': 513788116,
#   'btcPriceText': '0.095',
#   'localPriceText': '&euro;22',
#   'shipsFrom': 'Germany',
#   'isTrustedSeller': True,
#   'domesticCurrencyValue': None,
#   'escrowMethod': 'No'},
#  {'lid': '3212',
#   'lnk': '333423.979589',
#   'title': 'Afghan Soft Squidge - 50g',
#   'imageId': '91125.196271',
#   'sellerOutLink': -1377523590,
#   'btcPriceText': '0.668',
#   'localPriceText': '&pound;110',
#   'shipsFrom': 'UK',
#   'isTrustedSeller': True,
#   'domesticCurrencyValue': None,
#   'escrowMethod': 'No'},
#  {'lid': '4095',
#   'lnk': '124000.84443',
#   'title': 'Ak 47 5g',
#   'imageId': '719051.502618',
#   'sellerOutLink': 513788116,
#   'btcPriceText': '0.2118',
#   'localPriceText': '&euro;49',
#   'shipsFrom': 'Germany',
#   'isTrustedSeller': True,
#   'domesticCurrencyValue': None,
#   'escrowMethod': 'No'},
#  {'lid': '4933',
#   'lnk': '474188.554078',
#   'title': '2 grams ORANGE BUD || HOLLAND || AAA+++',
#   'imageId': '286457.991974',
#   'sellerOutLink': -2081707471,
#   'btcPriceText': '0.1041304',
#   'localPriceText': None,
#   'shipsFrom': 'eu',
#   'isTrustedSeller': True,
#   'domesticCurrencyValue': None,
#   'escrowMethod': 'Yes'},
#  {'lid': '357',
#   'lnk': '350458.426869',
#   'title': 'Onestoppornoshop.com - [PORN PREMIUM ACCOUNT]',
#   'imageId': '66326.676283',
#   'sellerOutLink': -1350947825,
#   'btcPriceText': '0.0394',
#   'localPriceText': '$10',
#   'shipsFrom': '',
#   'isTrustedSeller': True,
#   'domesticCurrencyValue': None,
#   'escrowMethod': 'Yes'},
#  {'lid': '3629',
#   'lnk': '34295.905377',
#   'title': 'PORN FULL COLLECTION - [LIFETIME PORN ACCOUNTS]',
#   'imageId': '415938.960452',
#   'sellerOutLink': -1350947825,
#   'btcPriceText': '0.197',
#   'localPriceText': '$49.99',
#   'shipsFrom': 'TOR',
#   'isTrustedSeller': True,
#   'domesticCurrencyValue': None,
#   'escrowMethod': 'Yes'},
#  {'lid': '6495',
#   'lnk': '810900.306413',
#   'title': '1g BTH',
#   'imageId': '162938.298163',
#   'sellerOutLink': 1916090551,
#   'btcPriceText': '0.493',
#   'localPriceText': '$125',
#   'shipsFrom': 'USA',
#   'isTrustedSeller': True,
#   'domesticCurrencyValue': None,
#   'escrowMethod': 'No'},
#  {'lid': '5530',
#   'lnk': '576442.782663',
#   'title': '50g  M.D.M.A Rocks  85%+',
#   'imageId': '363151.536158',
#   'sellerOutLink': -1377523590,
#   'btcPriceText': 2.675,
#   'localPriceText': '&pound;440',
#   'shipsFrom': 'UK',
#   'isTrustedSeller': True,
#   'domesticCurrencyValue': None,
#   'escrowMethod': 'No'},
#  {'lid': '3679',
#   'lnk': '10762.911493',
#   'title': 'Korova Black Bar (CAUTION EXTREMELY POTENT)',
#   'imageId': '723820.107849',
#   'sellerOutLink': 1916090551,
#   'btcPriceText': '0.296',
#   'localPriceText': '$75',
#   'shipsFrom': 'USA',
#   'isTrustedSeller': True,
#   'domesticCurrencyValue': None,
#   'escrowMethod': 'No'},
#  {'lid': '6231',
#   'lnk': '541621.970577',
#   'title': '1g of BBX',
#   'imageId': '15536.150197',
#   'sellerOutLink': 1916090551,
#   'btcPriceText': '0.0789',
#   'localPriceText': '$20',
#   'shipsFrom': 'USA',
#   'isTrustedSeller': True,
#   'domesticCurrencyValue': None,
#   'escrowMethod': 'No'},
#  {'lid': '3383',
#   'lnk': '922848.991769',
#   'title': '15g 8 slate pollen',
#   'imageId': '937319.565940',
#   'sellerOutLink': -1377523590,
#   'btcPriceText': '0.3648',
#   'localPriceText': '&pound;60',
#   'shipsFrom': 'UK',
#   'isTrustedSeller': True,
#   'domesticCurrencyValue': None,
#   'escrowMethod': 'No'},
#  {'lid': '4174',
#   'lnk': '456539.31',
#   'title': '28g (1oz) of Crystal Meth(Straight from Mexico)',
#   'imageId': '670850.856888',
#   'sellerOutLink': 1916090551,
#   'btcPriceText': 4.73,
#   'localPriceText': '$1200',
#   'shipsFrom': 'USA',
#   'isTrustedSeller': True,
#   'domesticCurrencyValue': None,
#   'escrowMethod': 'No'},
#  {'lid': '3390',
#   'lnk': '417913.101737',
#   'title': '25g For Fucks Sake" Pollen',
#   'imageId': '595494.194655',
#   'sellerOutLink': -1377523590,
#   'btcPriceText': '0.638',
#   'localPriceText': '&pound;105',
#   'shipsFrom': 'UK',
#   'isTrustedSeller': True,
#   'domesticCurrencyValue': None,
#   'escrowMethod': 'No'},
#  {'lid': '2552',
#   'lnk': '980392.237748',
#   'title': 'ecstasy pills - 5 x purple/pink halloween pumpkins',
#   'imageId': '457658.4777',
#   'sellerOutLink': -1198629829,
#   'btcPriceText': '0.0986',
#   'localPriceText': '$25',
#   'shipsFrom': 'europe',
#   'isTrustedSeller': True,
#   'domesticCurrencyValue': None,
#   'escrowMethod': 'Yes'},
#  {'lid': '3206',
#   'lnk': '444101.251945',
#   'title': 'S5 HAZE 5g',
#   'imageId': '272890.222893',
#   'sellerOutLink': -1377523590,
#   'btcPriceText': '0.2858',
#   'localPriceText': '&pound;47',
#   'shipsFrom': 'UK ',
#   'isTrustedSeller': True,
#   'domesticCurrencyValue': None,
#   'escrowMethod': 'No'},
#  {'lid': '3207',
#   'lnk': '444723.859171',
#   'title': 'S5 HAZE 1.5g',
#   'imageId': '272890.222893',
#   'sellerOutLink': -1377523590,
#   'btcPriceText': '0.1216',
#   'localPriceText': '&pound;20',
#   'shipsFrom': 'UK',
#   'isTrustedSeller': True,
#   'domesticCurrencyValue': None,
#   'escrowMethod': 'No'},
#  {'lid': '5845',
#   'lnk': '768194.957279',
#   'title': 'Morphin Sulphate 100mg',
#   'imageId': '959973.479757',
#   'sellerOutLink': -1751609224,
#   'btcPriceText': '0.0864',
#   'localPriceText': '&euro;20',
#   'shipsFrom': 'Germany',
#   'isTrustedSeller': True,
#   'domesticCurrencyValue': None,
#   'escrowMethod': 'Yes'}]

# %%
json.loads(soup.find_all('script')[2].get_text().split("\n\n\t\n\n\t")[0].split('= ')[1][:-1])
# Out:
# {'-1377523590': {'jsVendorLink': '\n\t\t\t\t\t<a href="./contactMember?member=monetka"> monetka   </a>  <a class="viewRatings" href="./memberFeedback?member=monetka" target="_blank">  <span title="Successful transactions">(182)</span> (<span class="userRating gold" \n\t\t\ttitle="Average seller rating out of 182 rating[s] (1-5 stars)" >4.9&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</span>)</a> (<span class="agoraLinkedUserRating"\n\t\t\t\t\t\t\t\ttitle="Vendor rating on Agora (Deal count, Average Rating out of 5 stars)">55, 4.81/5</span>) (<span class="blackBankLinkedUserRating"\n\t\t\t\t\t\t\t\ttitle="Vendor rating on Black Bank (positive/neutral/negative)">27/1/0</span>) (<span class="nucleusLinkedUserRating"\n\t\t\t\t\t\t\ttitle="Nucleus vendor rating (Deal count, Average Rating out of 5 stars)">46, 4.8/5</span>)',
#   'jsVendorShipsFrom': 'United Kingdom'},
#  '513788116': {'jsVendorLink': '\n\t\t\t\t\t<a href="./contactMember?member=TheHeissenberg"> TheHeissenberg   </a>  <a class="viewRatings" href="./memberFeedback?member=TheHeissenberg" target="_blank">  <span title="Successful transactions">(156)</span> (<span class="userRating gold" \n\t\t\ttitle="Average seller rating out of 156 rating[s] (1-5 stars)" >4.8&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</span>)</a>',
#   'jsVendorShipsFrom': 'Germany'},
#  '-1350947825': {'jsVendorLink': '\n\t\t\t\t\t<a href="./contactMember?member=NotoSeller"> NotoSeller   </a>  <a class="viewRatings" href="./memberFeedback?member=NotoSeller" target="_blank">  <span title="Successful transactions">(63)</span> (<span class="userRating gold" \n\t\t\ttitle="Average seller rating out of 63 rating[s] (1-5 stars)" >5.0&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</span>)</a> (<span class="agoraLinkedUserRating"\n\t\t\t\t\t\t\t\ttitle="Vendor rating on Agora (Deal count, Average Rating out of 5 stars)">2000, 4.967/5</span>)',
#   'jsVendorShipsFrom': 'Worldwide'},
#  '-2081707471': {'jsVendorLink': '\n\t\t\t\t\t<a href="./contactMember?member=LockAndStock"> LockAndStock   </a>  <a class="viewRatings" href="./memberFeedback?member=LockAndStock" target="_blank">  <span title="Successful transactions">(138)</span> (<span class="userRating gold" \n\t\t\ttitle="Average seller rating out of 138 rating[s] (1-5 stars)" >4.9&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</span>)</a>',
#   'jsVendorShipsFrom': 'Netherlands'},
#  '653986930': {'jsVendorLink': '\n\t\t\t\t\t<a href="./contactMember?member=DrogMann"> DrogMann   </a>  <a class="viewRatings" href="./memberFeedback?member=DrogMann" target="_blank">  <span title="Successful transactions">(179)</span> (<span class="userRating gold" \n\t\t\ttitle="Average seller rating out of 179 rating[s] (1-5 stars)" >5.0&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</span>)</a>',
#   'jsVendorShipsFrom': 'Germany'},
#  '1916090551': {'jsVendorLink': '\n\t\t\t\t\t<a href="./contactMember?member=GuMbA2"> GuMbA2   </a>  <a class="viewRatings" href="./memberFeedback?member=GuMbA2" target="_blank">  <span title="Successful transactions">(537)</span> (<span class="userRating gold" \n\t\t\ttitle="Average seller rating out of 537 rating[s] (1-5 stars)" >4.9&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</span>)</a> (<span class="blackBankLinkedUserRating"\n\t\t\t\t\t\t\t\ttitle="Vendor rating on Black Bank (positive/neutral/negative)">307/3/3</span>)',
#   'jsVendorShipsFrom': 'United States'},
#  '1412451852': {'jsVendorLink': '\n\t\t\t\t\t<a href="./contactMember?member=JamrockFille"> JamrockFille   </a>  <a class="viewRatings" href="./memberFeedback?member=JamrockFille" target="_blank">  <span title="Successful transactions">(15)</span> (<span class="userRating gold" \n\t\t\ttitle="Average seller rating out of 15 rating[s] (1-5 stars)" >5.0&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</span>)</a>',
#   'jsVendorShipsFrom': 'Worldwide'},
#  '-1198629829': {'jsVendorLink': '\n\t\t\t\t\t<a href="./contactMember?member=Nooogz"> Nooogz   </a>  <a class="viewRatings" href="./memberFeedback?member=Nooogz" target="_blank">  <span title="Successful transactions">(151)</span> (<span class="userRating gold" \n\t\t\ttitle="Average seller rating out of 151 rating[s] (1-5 stars)" >4.9&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</span>)</a>',
#   'jsVendorShipsFrom': 'Europe'},
#  '-1751609224': {'jsVendorLink': '\n\t\t\t\t\t<a href="./contactMember?member=UncleMorpheus"> UncleMorpheus   </a>  <a class="viewRatings" href="./memberFeedback?member=UncleMorpheus" target="_blank">  <span title="Successful transactions">(2)</span> (<span class="userRating gold" \n\t\t\ttitle="Average seller rating out of 2 rating[s] (1-5 stars)" >5.0&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</span>)</a> (<span class="bmrLinkedUserRating"\n\t\t\t\t\t\t\t\ttitle="User rating on Black Market Reloaded (positive/neutral/negative)">135/3/2</span>)',
#   'jsVendorShipsFrom': 'Germany'}}
